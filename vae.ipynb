# %%
# https://avandekleut.github.io/vae/

# %% [markdown]
# # Motivation
#
# Imagine that we have a large, high-dimensional dataset. For example, imagine we have a dataset consisting of thousands of images. Each image  is made up of hundreds of pixels, so each data point has hundreds of dimensions. The **[manifold hypothesis](https://deepai.org/machine-learning-glossary-and-terms/manifold-hypothesis)** states that real-world high-dimensional data actually consists of low-dimensional data that is embedded in the high-dimensional space. This means that, while the actual data itself might have hundreds of dimensions, the underlying structure of the data can be sufficiently described using only a few dimensions.
#
# This is the motivation behind dimensionality reduction techniques, which try to take high-dimensional data and project it onto a lower-dimensional surface. For humans who visualize most things in 2D (or sometimes 3D), this usually means projecting the data onto a 2D surface. Examples of dimensionality reduction techniques include [principal component analysis (PCA)](https://en.wikipedia.org/wiki/Principal_component_analysis) and [t-SNE](https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding). Chris Olah's blog has a [great post](https://colah.github.io/posts/2014-10-Visualizing-MNIST/) reviewing some dimensionality reduction techniques applied to the MNIST dataset.

# %% [markdown]
# Neural networks are often used in the **supervised learning** context, where data consists of pairs $(x, y)$ and the network learns a function $f:X \to Y$. This context applies to both regression (where $y$ is a continuous function of $x$) and classification (where $y$ is a discrete label for $x$). However, neural networks have shown considerable power in the **unsupervised learning** context, where data just consists of points $x$. There are no "targets" or "labels" $y$. Instead, the goal is to learn and understand the structure of the data. In the case of dimensionality reduction, the goal is to find a low-dimensional representation of the data.
#
# # Autoencoders
#
# Autoencoders are a special kind of neural network used to perform dimensionality reduction. We can think of autoencoders as being composed of two networks, an **encoder** $e$ and a **decoder** $d$.
#
# The encoder learns a non-linear transformation $e:X \to Z$ that projects the data from the original high-dimensional input space $X$ to a lower-dimensional **latent space** $Z$. We call $z = e(x)$ a **latent vector**. A latent vector is a low-dimensional representation of a data point that contains information about $x$. The transformation $e$ should have certain properties, like similar values of $x$ should have similar latent vectors (and dissimilar values of $x$ should have dissimilar latent vectors).
#
# A decoder learns a non-linear transformation $d: Z \to X$ that projects the latent vectors back into the original high-dimensional input space $X$. This transformation should take the latent vector $z = e(x)$ and reconstruct the original input data $\hat{x} = d(z) = d(e(x))$.
#
# An autoencoder is just the composition of the encoder and the decoder $f(x) = d(e(x))$. The autoencoder is trained to minimize the difference between the input $x$ and the reconstruction $\hat{x}$ using a kind of **reconstruction loss**. Because the autoencoder is trained as a whole (we say it's trained "end-to-end"), we simultaneosly optimize the encoder and the decoder.

# %% [markdown]
# ![autoencoder](autoencoder.png)

# %% [markdown]
# Below is an implementation of an autoencoder written in PyTorch. We apply it to the MNIST dataset.

# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
import torchvision
import numpy as np
import matplotlib.pyplot as plt; plt.rcParams['figure.dpi'] = 200

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Below we write the `Encoder` class by sublcassing `torch.nn.Module`, which lets us define the `__init__` method storing layers as an attribute, and a `forward` method describing the forward pass of the network.

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dims):
        super(Encoder, self).__init__()
        self.linear1 = nn.Linear(784, 512)
        self.linear2 = nn.Linear(512, latent_dims)
    
    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        return self.linear2(x)

# %% [markdown]
# We do something similar for the `Decoder` class, ensuring we reshape the output.

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dims):
        super(Decoder, self).__init__()
        self.linear1 = nn.Linear(latent_dims, 512)
        self.linear2 = nn.Linear(512, 784)
        
    def forward(self, z):
        z = F.relu(self.linear1(z))
        z = torch.sigmoid(self.linear2(z))
        return z.reshape((-1, 1, 28, 28))

# %% [markdown]
# FInally, we write an `Autoencoder` class that combines these two. Note that we could have easily written this entire autoencoder as a single neural network, but splitting them in two makes it conceptually clearer.

# %%
class Autoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(Autoencoder, self).__init__()
        self.encoder = Encoder(latent_dims)
        self.decoder = Decoder(latent_dims)
    
    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %% [markdown]
# Next, we will write some code to train the autoencoder on the MNIST dataset.

# %%
def train(autoencoder, data, epochs=20):
    opt = torch.optim.Adam(autoencoder.parameters())
    for epoch in range(epochs):
        for x, y in data:
            x = x.to(device) # GPU
            opt.zero_grad()
            x_hat = autoencoder(x)
            loss = ((x - x_hat)**2).sum()
            loss.backward()
            opt.step()
    return autoencoder

# %%
latent_dims = 2
autoencoder = Autoencoder(latent_dims).to(device) # GPU

data = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('./data', 
               transform=torchvision.transforms.ToTensor(), 
               download=True),
        batch_size=128,
        shuffle=True)

autoencoder = train(autoencoder, data)

# %% [markdown]
# What should we look at once we've trained an autoencoder? I think that the following things are useful:
#
# 1. Look at the latent space. If the latent space is 2-dimensional, then we can transform a batch of inputs $x$ using the encoder and make a scatterplot of the output vectors. Since we also have access to labels for MNIST, we can colour code the outputs to see what they look like.
# 2. Sample the latent space to produce output. If the latent space is 2-dimensional, we can sample latent vectors $z$ from the latent space over a uniform grid and plot the decoded latent vectors on a grid.

# %%
def plot_latent(autoencoder, data, num_batches=100):
    for i, (x, y) in enumerate(data):
        z = autoencoder.encoder(x.to(device))
        z = z.to('cpu').detach().numpy()
        plt.scatter(z[:, 0], z[:, 1], c=y, cmap='tab10')
        if i > num_batches:
            plt.colorbar()
            break

# %%
plot_latent(autoencoder, data)

# %% [markdown]
# The resulting latent vectors cluster similar digits together. We can also sample uniformly from the latent space and see how the decoder reconstructs inputs from arbitrary latent vectors.

# %%
def plot_reconstructed(autoencoder, r0=(-5, 10), r1=(-10, 5), n=12):
    w = 28
    img = np.zeros((n*w, n*w))
    for i, y in enumerate(np.linspace(*r1, n)):
        for j, x in enumerate(np.linspace(*r0, n)):
            z = torch.Tensor([[x, y]]).to(device)
            x_hat = autoencoder.decoder(z)
            x_hat = x_hat.reshape(28, 28).to('cpu').detach().numpy()
            img[(n-1-i)*w:(n-1-i+1)*w, j*w:(j+1)*w] = x_hat
    plt.imshow(img, extent=[*r0, *r1])

# %%
plot_reconstructed(autoencoder)

# %% [markdown]
# We intentionally plot the reconstructed latent vectors using approximately the same range of values taken on by the actual latent vectors. We can see that the reconstructed latent vectors look like digits, and the kind of digit corresponds to the location of the latent vector in the latent space.

# %% [markdown]
# You may have noticed that there are "gaps" in the latent space, where data is never mapped to. This becomes a problem when we try to use autoencoders as **generative models**. The goal of generative models is to take a data set $X$ and produce more data points from the same distribution that $X$ is drawn from. For autoencoders, this means sampling latent vectors $z \sim Z$ and then decoding the latent vectors to produce images. If we sample a latent vector from a region in the latent space that was never seen by the decoder during training, the output might not make any sense at all. We see this in the top left corner of the `plot_reconstructed` output, which is empty in the latent space, and the corresponding decoded digit does not match any existing digits.

# %% [markdown]
# # Variational Autoencoders
#
# The only constraint on the latent vector representation for traditional autoencoders is that latent vectors should be easily decodable back into the original image. As a result, the latent space $Z$ can become disjoint and non-continuous. Variational autoencoders try to solve this problem.
#
# In traditional autoencoders, inputs are mapped deterministically to a latent vector $z = e(x)$. In variational autoencoders, inputs are mapped to a probability distribution over latent vectors, and a latent vector is then sampled from that distribution. The decoder becomes more robust at decoding latent vectors as a result.
#
# Specifically, instead of mapping the input $x$ to a latent vector $z = e(x)$, we map it instead to a mean vector $\mu(x)$ and a vector of standard deviations $\sigma(x)$. These parametrize a diagonal Gaussian distribution $\mathcal{N}(\mu, \sigma)$, from which we then sample a latent vector $z \sim \mathcal{N}(\mu, \sigma)$.
#
# This is generally accomplished by replacing the last layer of a traditional autoencoder with two layers, each of which output $\mu(x)$ and $\sigma(x)$. An exponential activation is often added to $\sigma(x)$ to ensure the result is positive.

# %% [markdown]
# ![variational autoencoder](variational-autoencoder.png)

# %% [markdown]
# However, this does not completely solve the problem. There may still be gaps in the latent space because the outputted means may be significantly different and the standard deviations may be small. To reduce that, we add an **auxillary loss** that penalizes the distribution $p(z \mid x)$ for being too far from the standard normal distribution $\mathcal{N}(0, 1)$. This penalty term is the KL divergence between $p(z \mid x)$ and $\mathcal{N}(0, 1)$, which is given by
# $$
# \mathbb{KL}\left( \mathcal{N}(\mu, \sigma) \parallel \mathcal{N}(0, 1) \right) = \sum_{x \in X} \left( \sigma^2 + \mu^2 - \log \sigma - \frac{1}{2} \right)
# $$

# %% [markdown]
# This expression applies to two univariate Gaussian distributions (the full expression for two arbitrary univariate Gaussians is derived in [this math.stackexchange post](https://stats.stackexchange.com/questions/7440/kl-divergence-between-two-univariate-gaussians)). Extending it to our diagonal Gaussian distributions is not difficult; we simply sum the KL divergence for each dimension.
#
# This loss is useful for two reasons. First, we cannot train the encoder network by gradient descent without it, since gradients cannot flow through sampling (which is a non-differentiable operation). Second, by penalizing the KL divergence in this manner, we can encourage the latent vectors to occupy a more centralized and uniform location. In essence, we force the encoder to find latent vectors that approximately follow a standard Gaussian distribution that the decoder can then effectively decode.

# %% [markdown]
# To implement this, we do not need to change the `Decoder` class. We only need to change the `Encoder` class to produce $\mu(x)$ and $\sigma(x)$, and then use these to sample a latent vector. We also use this class to keep track of the KL divergence loss term.

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalEncoder, self).__init__()
        self.linear1 = nn.Linear(784, 512)
        self.linear2 = nn.Linear(512, latent_dims)
        self.linear3 = nn.Linear(512, latent_dims)
        
        self.N = torch.distributions.Normal(0, 1)
        self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
        self.N.scale = self.N.scale.cuda()
        self.kl = 0
    
    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        mu =  self.linear2(x)
        sigma = torch.exp(self.linear3(x))
        z = mu + sigma*self.N.sample(mu.shape)
        self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return z

# %% [markdown]
# The autoencoder class changes a single line of code, swappig out an `Encoder` for a `VariationalEncoder`.

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = Decoder(latent_dims)
    
    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %% [markdown]
# In order to train the variational autoencoder, we only need to add the auxillary loss in our training algorithm.
#
# The following code is essentially copy-and-pasted from above, with a single term added added to the loss (`autoencoder.encoder.kl`).

# %%
def train(autoencoder, data, epochs=20):
    opt = torch.optim.Adam(autoencoder.parameters())
    for epoch in range(epochs):
        for x, y in data:
            x = x.to(device) # GPU
            opt.zero_grad()
            x_hat = autoencoder(x)
            loss = ((x - x_hat)**2).sum() + autoencoder.encoder.kl
            print(loss)
            loss.backward()
            opt.step()
    return autoencoder

# %%
vae = VariationalAutoencoder(latent_dims).to(device) # GPU
vae = train(vae, data)
# Out:
# tensor(23875.6777, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(21519.6387, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(19479.0898, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(17183.9727, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(14995.3242, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(12724.4795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(11307.9473, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(10356.0332, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(10343.3994, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(9433.2529, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(9069.4102, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(9359.7998, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(8990.1064, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(8801.5742, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(8304.6426, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(8049.7026, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7807.3652, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7998.0063, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7778.7007, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7783.3320, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(8057.9111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7620.5347, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7434.0459, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7646.6250, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7480.0142, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7560.3389, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7677.2949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7769.7490, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7431.1743, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7535.6733, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7615.3667, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6909.5312, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7419.5347, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7089.4258, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7263.2803, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6992.2373, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7084.4277, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7001.9165, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7270.6094, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7287.1484, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7086.4058, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7148.6904, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7122.0474, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6942.2344, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7246.0293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7032.7451, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7024.7246, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6860.8911, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7037.7334, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6763.3096, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(7153.1904, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6891.3394, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6972.5557, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6996.9395, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6897.2446, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6842.5488, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6614.2461, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6613.9053, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6939.8701, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6769.5039, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6737.8667, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6983.3022, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6326.5376, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6421.5913, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6981.1025, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6540.4897, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6637.1714, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6722.1128, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6627.4307, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6675.9355, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6651.9292, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6533.5029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6574.9351, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6518.4751, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6561.8047, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6628.0332, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6818.8848, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6931.6646, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6693.0308, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6730.5435, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6410.3911, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6663.0957, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6637.7314, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6636.8760, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6194.1880, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6521.3911, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6437.3467, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6302.7432, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6438.1592, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6427.5176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6218.4634, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6554.6016, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6445.7319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6544.0835, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6416.2104, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6545.7236, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6504.2910, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6418.7617, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6701.8975, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6410.1221, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6224.0894, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6689.2207, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6448.4346, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6789.5420, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6931.2910, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6509.9492, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6422.7100, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6352.7896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6609.1631, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6688.0488, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6294.9219, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6579.2520, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6277.8418, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6279.3315, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6423.1670, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6114.1421, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6151.1025, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6371.4272, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6136.9126, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6113.0127, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6631.6348, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5902.1372, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6321.1733, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6276.4580, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6474.2764, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6651.2856, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6527.1621, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6398.9795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6174.1953, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6225.0186, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6452.5498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6012.7246, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6158.9189, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6596.1978, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6437.6655, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6262.3403, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6098.2544, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6256.0249, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6222.2021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6303.1899, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6442.4790, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6076.5396, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6435.6924, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6408.4116, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6321.8867, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6664.5854, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6369.8130, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6566.4858, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6494.1841, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6044.0454, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6528.5698, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6389.8682, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6296.2593, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6168.7466, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6249.1021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6584.9736, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6387.2573, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6338.7148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6133.3687, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6264.4072, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6257.3501, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6065.0405, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6147.5327, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6283.0288, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6356.0518, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6332.0381, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5965.6572, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6093.1177, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6146.9316, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6182.5029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6458.6855, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6040.9092, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6298.0659, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6430.6216, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5870.1230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6370.8374, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6029.1250, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6196.2251, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6107.7212, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6361.1089, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6102.7246, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6601.8032, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6119.6021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6244.9043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6184.2026, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6018.5269, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5909.1431, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5948.4697, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6174.8271, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6273.5063, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5909.2349, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6051.8496, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6071.9346, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6104.7715, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6057.3853, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6091.7622, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5934.3784, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6141.9453, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5840.7754, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6131.9282, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6047.6855, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5988.5322, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5995.8164, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6169.2021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5959.7617, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6121.2017, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5905.7900, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6128.6929, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5702.3184, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5924.7129, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5850.7197, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5669.6475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6375.4482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6179.2188, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5834.5137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5697.0464, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5984.7002, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6236.0684, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5891.0640, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6085.7231, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6188.6416, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5996.5288, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6295.5264, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5792.8145, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6046.8438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6153.2476, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6246.7827, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6208.7041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5915.7993, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5914.9814, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5994.4604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5823.6650, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6099.4487, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5824.5186, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5721.6016, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5996.4111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5997.3071, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5971.3115, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5838.9780, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6112.4121, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5884.2734, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5868.8853, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6181.0059, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6080.4429, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5812.7510, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5969.6426, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6207.3408, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5806.0693, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5888.8091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6100.8291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5930., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5996.0171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5917.6382, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5859.0527, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5910.8335, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5929.5278, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5628.4917, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5806.5171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5845.4604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6013.4150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5864.2329, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5586.8257, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6282.3164, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5794.4385, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5839.7329, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5799.2715, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5962.5923, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5749.7822, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5816.6621, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6121.9526, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5398.6162, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6080.8208, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5599.5830, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5633.6660, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5542.6987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5846.6992, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5816.5195, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6190.1685, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5784.6489, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6066.4058, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5918.8086, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5661.8438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5886.8687, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5757.9917, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5827.0679, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5692.2319, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5528.5566, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5515.1187, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5877.2334, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5594.8940, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5606.4463, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5396.0459, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5750.1846, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5686.6665, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5628.5044, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5524.8130, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5547.9624, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5841.6768, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5769.0137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5787.7183, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5848.8853, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5738.7695, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5628.0039, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5878.8286, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5882.3091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5404.3408, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6032.5771, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5677.7554, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5746.3467, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5814.1440, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5970.9604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6112.8384, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5721.1484, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5986.4336, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5766.5796, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6019.5195, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6024.8584, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5932.8623, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5680.8638, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5584.5063, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5473.2891, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5807.2334, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5716.9824, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5726.3145, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5525.4414, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5825.7407, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5903.9160, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5588.8433, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5797.4360, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5708.4004, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5757.8408, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5581.3252, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5566.1128, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5855.2642, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5797.4409, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5772.4062, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5654.4375, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5471.8076, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5687.0454, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5662.8979, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5491.6353, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5534.8008, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5743.0708, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5911.4463, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5585.5903, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5792.1309, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5842.9785, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5697.9736, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5658.0361, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5555.7388, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5557.2783, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5713.8911, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5904.0176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5791.6562, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5472.4648, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5519.5034, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5356.1475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5452.6748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5806.2915, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5587.3359, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5425.5503, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5828.2798, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5384.3984, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5426.4077, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5669.6406, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5854.9893, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5576.6826, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5796.4111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5866.9785, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5730.7266, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5806.8701, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5657.0225, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5875.9155, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5767.0264, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5678.0308, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5617.7480, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5854.3301, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5814.0190, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5730.1753, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5937.6108, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5500.7524, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5785.8042, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5904.2969, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5526.4204, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5599.4414, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5460.6426, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5889.7368, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5939.4048, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5684.5356, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5559.3413, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5684.0586, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5569.6797, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5776.8091, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5758.4424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5763.0005, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5534.5479, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5156.5444, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5574.2134, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5649.6948, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5341.1094, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5416.0063, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5648.4111, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5438.2563, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5565.6729, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5518.1187, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5449.5234, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5702.2388, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5601.8594, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5410.5845, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5509.7471, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5911.2529, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5507.5391, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5919.5552, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5597.6357, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5607.3809, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5650.7168, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5545.8228, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5622.6406, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5394.5469, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5657.6230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5670.8848, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5398.5610, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5727.8765, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5653.3877, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5334.4131, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5528.0518, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5361.8477, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5707.7949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5668.7227, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5619.1201, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5721.3477, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5587.8101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5572.3564, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5722.3892, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5869.1294, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5528.8887, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5741.3110, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5633.4419, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5434.3340, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5330.4873, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5643.8315, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5422.6118, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5821.1934, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5178.3506, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5575.4917, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5642.0190, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5564.2358, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5837.2017, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5467.1123, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5554.1274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5721.2920, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5821.0830, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(6003.7935, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5216.8438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5504.1274, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5395.2061, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5606.8706, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5471.8901, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5723.0859, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5615.8096, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5625.2041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5451.4150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5614.2012, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5462.0532, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5531.3257, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5357.8281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5371.2095, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5707.5771, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3881.0972, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5524.0469, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5453.2915, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5746.9756, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5527.3105, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5877.9199, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5604.5938, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5835.3989, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5101.8125, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5628.5161, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5543.6733, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5609.8457, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5564.0688, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5777.0303, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5603.0913, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5682.4561, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5575.9375, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5612.0293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5488.1084, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5612.6558, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5212.1387, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5550.7407, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5475.5352, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5694.2607, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5478.9683, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5455.9800, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5401.1455, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5544.2729, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5387.5869, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5293.3667, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5484.4424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5392.5908, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5525.5898, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5564.3291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5510.6240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5545.5039, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5340.2725, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5378.6157, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5634.9580, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5322.1055, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5549.8965, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5398.7021, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5315.9292, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5335.9077, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5481.2129, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5598.3096, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5550.1104, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5865.8247, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5557.9121, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5645.7275, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5309.4795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5857.9194, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5505.2705, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5473.4038, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5850.8799, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5426.9321, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5487.0190, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5386.3130, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5450.3350, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5460.3369, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5529.1338, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5700.9531, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5479.1538, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5383.5000, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5496.3789, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5378.6777, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5627.5913, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5352.5752, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5191.7905, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5727.4404, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5719.4287, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5285.7876, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5379.9868, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5307.4014, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5580.0850, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5666.7012, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5616.6763, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5637.4692, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5234.7729, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5149.1704, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5204.0972, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5046.0371, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5625.8862, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5544.3555, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5660.3950, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5566.0654, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5362.3433, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5730.4639, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5549.4375, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5235.5107, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5500.8262, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5406.2188, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5596.2944, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5719.3291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5539.1958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5651.4624, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5417.1187, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5441.6206, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5665.8486, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5498.2124, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5420.5303, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5508.8691, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5788.9780, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5471.4434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5344.1128, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5387.7588, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5407.5332, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5599.6777, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5431.0146, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5740.5000, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5485.9951, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5373.5308, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5446.1646, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5641.6982, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5273.7759, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5392.1279, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5615.3301, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5454.0464, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5406.4258, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5492.5176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5330.3828, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5190.9990, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5310.4199, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5569.3701, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5837.6655, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5528.5054, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5598.3057, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5473.5244, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5183.5112, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5387.0864, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5295.0337, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5598.2832, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5620.3525, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5599.0605, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5628.3687, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5278.6406, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5404.0146, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5301.3867, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5230.1011, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5378.4795, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5669.1479, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5871.8496, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5165.2251, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5654.2397, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5348.5400, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5591.4497, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5487.1958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5661.4224, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5656.0391, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5411.7920, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5348.4775, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5652.9033, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5306.3311, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5864.7734, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5557.1147, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5373.3516, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5572.2949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5343.1597, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5232.2539, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5586.5942, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5454.1719, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5588.2983, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5470.5073, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5547.6865, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5541.0029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5492.0269, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5482.3701, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5518.3257, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5610.4170, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5653.7988, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5680.0020, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5495.8564, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5564.1250, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5389.3560, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5541.5171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5675.6416, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5842.4067, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5451.9199, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5739.6592, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5808.9287, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5064.1729, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5741.6924, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5408.4062, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5588.1890, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5333.5283, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5559.9229, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5511.4492, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5340.4463, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5080.3037, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5271.4458, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5462.5928, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5780.0142, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5457.8999, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5409.7925, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5407.3125, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5591.3818, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5193.2227, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5665.7095, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5397.7925, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5499.7705, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5813.8101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5583.8477, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5537.9434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5386.4019, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5547.2358, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5715.6118, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5499.5063, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5080.7402, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5524.5718, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5378.3032, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5372.8853, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5474.4180, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5506.1309, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5306.7686, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5681.1821, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5364.1001, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5389.4038, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5187.4712, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5736.6895, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5385.3311, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5637.9961, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5425.3311, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5490.4863, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5360.5444, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5833.8530, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5444.2461, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5373.1821, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5522.4697, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5369.1567, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5523.6572, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5447.5117, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5754.3306, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5292.1763, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5375.6108, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5263.8560, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5222.1489, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5269.2715, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5355.8325, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5349.5161, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5696.1309, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5611.4546, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5292.2192, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5456.2529, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5424.9355, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5216.7363, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5175.8281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5157.4424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5228.0225, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5720.9624, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5769.4668, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5094.3291, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5425.1846, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5549.7651, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5398.5859, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5275.3940, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5437.5342, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5124.7080, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5479.8018, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4997.0293, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5597.2979, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5482.1548, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5645.7383, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5464.1797, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5367.3936, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5262.9321, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5377.1226, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5299.0210, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5580.2734, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5270.1631, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5361.3550, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5555.5757, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5310.0815, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5426.9482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5536.0186, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5573.7974, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5606.8022, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5244.5137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5254.3208, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5297.9248, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5319.1855, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5310.0889, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5150.2046, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5561.2554, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5766.9478, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5409.5200, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5228.8354, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5283.6260, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5305.2041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5315.0220, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5410.3633, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5598.6558, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5273.6641, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5409.1621, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5265.1914, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5503.0649, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5383.9390, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5059.8545, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5488.0586, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5314.9404, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5531.2812, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5426.8052, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5390.5098, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5426.0381, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5412.0361, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5573.0059, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5494.0420, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5251.1748, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5475.6230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5018.5479, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5760.8242, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5547.4771, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5472.6475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5621.0127, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5269.7129, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5725.2222, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5529.6475, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5619.0259, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5466.9121, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5429.8867, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5574.7910, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5490.4917, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5276.3359, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5403.7275, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5425.0176, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5419.4521, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5495.6392, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5535.3721, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5503.5454, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5184.6504, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5162.9102, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5467.7651, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5410.5693, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5336.2549, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5718.2944, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5267.7007, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5700.9482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5233.8301, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5333.8828, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5295.0278, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5299.7227, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5340.4990, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5200.2471, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5319.9375, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5392.4536, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5215.2007, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# tensor(4850.2051, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4915.6411, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4829.7607, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4843.8989, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4708.6230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4905.2959, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5270.9502, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4773.6562, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4906.2871, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4694.0859, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4809.7549, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4845.0088, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4836.3760, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4765.5508, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4673.6895, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4558.2588, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4716.9321, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5142.4077, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5045.2085, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5056.5068, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4988.0122, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4888.7661, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5155.6855, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4798.6191, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4884.1987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4736.3940, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5077.2549, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4831.9629, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4876.2329, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4650.8701, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5216.2793, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4720.2798, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4957.9707, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4700.0625, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4888.4673, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4622.1958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4726.9302, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5144.0264, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5183.6440, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4774.6372, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4661.2632, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4891.7910, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4757.4824, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5080.5029, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4823.1553, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4684.0708, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5016.6597, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4627.2812, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4844.4473, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4871.2617, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4763.8330, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4948.6553, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4879.7998, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4759.7173, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5312.8081, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5112.2993, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4546.7925, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4947.5083, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4736.8457, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5255.3057, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5058.8613, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4907.0278, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4994.6294, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4893.1191, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4754.0811, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4971.3848, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5008.5327, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4579.2520, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4890.3271, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5032.8398, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4950.9272, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4753.6260, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4555.2559, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4794.5020, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4872.8442, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4934.4399, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4854.8896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5072.2480, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5087.5498, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4780.4941, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4764.7500, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4564.8247, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5018.1855, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4749.7402, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5022.7402, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4825.3306, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4902.0688, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4810.2754, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4732.6909, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4725.1328, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4700.6230, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5128.8057, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4680.2256, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4939.9165, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4711.6558, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4873.2954, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4928.2896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4914.3281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5038.1201, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4908.6567, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4660.6914, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4682.4590, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4452.6543, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4837.2832, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4926.0645, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4787.7949, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4893.3711, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4650.9912, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5004.5581, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4949.9619, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5086.0049, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4739.2041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4939.5332, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4685.7637, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4925.8325, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4667.9434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4623.9438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4803.7173, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4536.8618, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4744.1821, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5151.6040, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4823.4087, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4981.1782, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4892.7446, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4930.5688, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5016.6450, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4901.1060, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5032.8101, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5090.8677, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4971.5757, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4923.2788, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4665.7939, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5044.7627, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4888.0693, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4812.7202, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4651.0674, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4657.4424, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5040.6821, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5046.1782, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5118.4644, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4768.6792, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4791.6479, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4580.6348, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4957.4775, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5102.2163, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5129.4155, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4832.8828, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4659.7617, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4918.7051, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5054.2148, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4774.9751, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4482.1802, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4950.8140, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4540.1904, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4711.6221, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4748.0103, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4776.5493, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4963.6514, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5146.7188, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4877.7881, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4816.2354, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4862.5850, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4703.8076, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4829.9751, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5137.9326, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4786.0005, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4909.8574, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4912.7617, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5024.8662, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5037.3223, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4705.4150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4796.5171, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4618.5845, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4855.3223, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4929.1987, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5018.6899, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4945.8604, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4941.6792, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4820.7544, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4865.8174, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4691.2344, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5046.7871, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4661.6616, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4483.9146, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4759.4434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4703.4741, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5139.9946, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4721.1699, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4930.7090, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4864.4434, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5029.5444, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5082.1191, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5017.4878, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4744.8281, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4711.8354, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5110.6558, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4657.6343, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4733.8271, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4848.1978, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4960.7061, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4744.6772, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4729.4307, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4895.7778, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4860.8711, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4909.9502, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5000.8438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4761.6763, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5324.4482, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4579.9346, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4840.8506, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5148.9438, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4745.5386, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5111.6958, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5095.5449, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5013.0449, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5028.9150, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4812.2041, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5046.5044, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4880.5693, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4880.8809, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5103.4658, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4723.3628, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4939.3047, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4625.5693, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4802.4126, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4829.0439, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4887.1123, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4876.3711, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4938.1353, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4788.7529, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4746.5630, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4547.9766, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4910.0215, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4925.4385, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4993.0625, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4926.5703, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5049.9146, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4938.4673, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5100.5391, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4469.5435, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4920.0132, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4810.6523, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4794.1670, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4981.1118, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4794.0137, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4695.1167, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5027.3286, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4986.8892, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4837.3901, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4781.1831, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5100.9819, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4990.6924, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5084.5156, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4718.5967, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4776.7178, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4587.9263, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4807.1816, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5111.7935, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4679.2461, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4875.9375, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4977.3896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4779.6240, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4790.4507, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4713.0215, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4845.3320, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4655.7603, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(5048.7080, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4885.9902, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4939.3853, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(4665.9043, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(3860.9705, device='cuda:0', grad_fn=<AddBackward0>)

# %% [markdown]
# Let's plot the latent vector representations of a few batches of data.

# %%
plot_latent(vae, data)

# %% [markdown]
# We can see that, compared to the traditional autoencoder, the range of values for latent vectors is much smaller, and more centralized. The distribution overall of $p(z \mid x)$ appears to be much closer to a Gaussian distribution.
#
# Let's also look at the reconstructed digits from the latent space:

# %%
plot_reconstructed(vae, r0=(-3, 3), r1=(-3, 3))

# %% [markdown]
# # Conclusions
#
# Variational autoencoders produce a latent space $Z$ that is more compact and smooth than that learned by traditional autoencoders. This lets us randomly sample points $z \sim Z$ and produce corresponding reconstructions $\hat{x} = d(z)$ that form realistic digits, unlike traditional autoencoders.

# %% [markdown]
# # Extra Fun

# %% [markdown]
# One final thing that I wanted to try out was **interpolation**. Given two inputs $x_1$ and $x_2$, and their corresponding latent vectors $z_1$ and $z_2$, we can interpolate between them by decoding latent vectors between $x_1$ and $x_2$.

# %% [markdown]
# The following code produces a row of images showing the interpolation between digits.

# %%
def interpolate(autoencoder, x_1, x_2, n=12):
    z_1 = autoencoder.encoder(x_1)
    z_2 = autoencoder.encoder(x_2)
    z = torch.stack([z_1 + (z_2 - z_1)*t for t in np.linspace(0, 1, n)])
    interpolate_list = autoencoder.decoder(z)
    interpolate_list = interpolate_list.to('cpu').detach().numpy()

    w = 28
    img = np.zeros((w, n*w))
    for i, x_hat in enumerate(interpolate_list):
        img[:, i*w:(i+1)*w] = x_hat.reshape(28, 28)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])

# %%
x, y = next(iter(data)) # hack to grab a batch
x_1 = x[y == 1][1].to(device) # find a 1
x_2 = x[y == 0][1].to(device) # find a 0

# %%
interpolate(vae, x_1, x_2, n=20)

# %%
interpolate(autoencoder, x_1, x_2, n=20)

# %% [markdown]
# I also wanted to write some code to generate a GIF of the transition, instead of just a row of images. The code below modifies the code above to produce a GIF.

# %%
from PIL import Image

def interpolate_gif(autoencoder, filename, x_1, x_2, n=100):
    z_1 = autoencoder.encoder(x_1)
    z_2 = autoencoder.encoder(x_2)
    
    z = torch.stack([z_1 + (z_2 - z_1)*t for t in np.linspace(0, 1, n)])
    
    interpolate_list = autoencoder.decoder(z)
    interpolate_list = interpolate_list.to('cpu').detach().numpy()*255
    
    images_list = [Image.fromarray(img.reshape(28, 28)).resize((256, 256)) for img in interpolate_list]
    images_list = images_list + images_list[::-1] # loop back beginning
    
    images_list[0].save(
        f'{filename}.gif', 
        save_all=True, 
        append_images=images_list[1:],
        loop=1)

# %%
interpolate_gif(vae, "vae", x_1, x_2)

# %% [markdown]
# <img src="vae.gif">

# %% [markdown]
# This post is inspired by these articles:
# - [Intuitively Understanding Variational Autoencoders](https://towardsdatascience.com/intuitively-understanding-variational-autoencoders-1bfe67eb5daf)
# - [Understanding Variational Autoencoders (VAEs)](https://towardsdatascience.com/understanding-variational-autoencoders-vaes-f70510919f73)
